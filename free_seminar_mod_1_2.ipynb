# %% [markdown]
# <a href="https://colab.research.google.com/github/ataevbaktygul/INIT_laboratory/blob/main/free_seminar_mod_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Данный сборник заданий предназначен для повтора и отработки тем modul_1 и modul_2

# %% [markdown]
# ## Вычислите.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $(\frac{x^3 x^4}{x^5})^{-6}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Решите уравнения!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Решите квадратные уравнения.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Сколько общих точек у графиков данных функций. Решить аналитически. Проверьте себя в Desmos
#
# $y = x^2 -2x + 4$
#
# $y = -3x + 5$

# %% [markdown]
# ### Решите неравенства.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \begin{cases}
#   -x^2 +5x -4 \geq 0       \\
#   x^2 -5x +6 < 0
# \end{cases}

# %% [markdown]
# # Задача.
#
# Мы изучили рынок недвижимости в городе "А" и городе "В".
#
# Будем считать закон зависимости стоимости $Pr$ в долларах от площади $S$ в сотках линейным.
#
# Для города "А" известно:
#
# $Pr(2) = 3000$
#
# $Pr(4) = 4000$
#
# Для города "B" известно:
#
# $Pr(2) = 4500$
#
# $Pr(4) = 5000$
#
# Начиная с какого значения площади участок в городе "В" стоит дешевле чем в  городе "А"?

# %% [markdown]
# ## Постройте графики функции.
#
# $y = x^2 - 4x + 3$
#
# $y = |x^2 - 7x + 6|$
#
# $y = x^2 -x|x-4| + 4$

# %% [markdown]
# # Экстремумы.
#
# Для нахождения абсциссы вершины можно пользоваться формулой:
#
# $x_{extr} = \frac{-b}{2a}$
#
# Найдите экстремумы функций:
#
# $y = x^2 -4x + 2$
#
# $y = -x^2 + 6x -1$
#
# $y = -3x^2 -12x + 1$

# %% [markdown]
# ## Задача.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Задаа сводится к исследования зависимости:
#
# $s = 4t^2 + (24-t)^2$

# %% [markdown]
# ## Задача.
#
# Найти размеры открытого бассейна в форме прямоугольного параллелепипеда с квадратным дном, имеющего объем 32 кв метра так, чтобы на облицовку его дна и стенок потребовалось наименьшее количество стройматериалов.
